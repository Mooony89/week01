# %%
import pandas as pd
import numpy as np
from IPython.display import Image
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
from sqlalchemy import create_engine

database_name = 'telecom'
table_name= 'xdr_data'

connection_params = { "host": "localhost", "user": "postgres", "password": "omlogin66",
                    "port": "5432", "database": database_name}

engine = create_engine(f"postgresql+psycopg2://{connection_params['user']}:{connection_params['password']}@{connection_params['host']}:{connection_params['port']}/{connection_params['database']}")

# str or SQLAlchemy Selectable (select or text object)
sql_query = 'SELECT * FROM xdr_data'

df = pd.read_sql(sql_query, con= engine)

# %%
# 1 Data screening
#An initial data screening process involves checking the dimensions of data, the types of variables, **missing or atypical values**

# %%
df
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN             None       NaN             None     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 149010 non-null  float64
#  1   Start                                     150000 non-null  object
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  object
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             148935 non-null  float64
#  8   IMEI                                      149429 non-null  float64
#  9   Last Location Name                        148848 non-null  object
# ...

# %%
### 1.2 Descriptive Analysis
#Numerical methods of extracting information from data. eg. what is the mean, mode, median, and variance?

df.describe()
# Out:
#           Bearer Id       Start ms         End ms     Dur. (ms)          IMSI  \
# count  1.490100e+05  150000.000000  150000.000000  1.500000e+05  1.494310e+05
# mean   1.013887e+19     499.188200     498.800880  1.046086e+05  2.082016e+14
# std    2.893173e+18     288.611834     288.097653  8.103762e+04  2.148809e+10
# min    6.917538e+18       0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%    7.349883e+18     250.000000     251.000000  5.744050e+04  2.082014e+14
# 50%    7.349883e+18     499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%    1.304243e+19     749.000000     750.000000  1.324302e+05  2.082018e+14
# max    1.318654e+19     999.000000     999.000000  1.859336e+06  2.140743e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   1.489350e+05  1.494290e+05    122172.000000    122189.000000
# mean    4.188282e+10  4.847455e+13       109.795706        17.662883
# ...

# %%
df.describe(include='all')
# Out:
#            Bearer Id           Start       Start ms             End  \
# count   1.490100e+05          150000  150000.000000          150000
# unique           NaN            9997            NaN            6403
# top              NaN  4/26/2019 7:25            NaN  4/25/2019 0:01
# freq             NaN             203            NaN            1150
# mean    1.013887e+19             NaN     499.188200             NaN
# std     2.893173e+18             NaN     288.611834             NaN
# min     6.917538e+18             NaN       0.000000             NaN
# 25%     7.349883e+18             NaN     250.000000             NaN
# 50%     7.349883e+18             NaN     499.000000             NaN
# 75%     1.304243e+19             NaN     749.000000             NaN
# max     1.318654e+19             NaN     999.000000             NaN
#
#                End ms     Dur. (ms)          IMSI  MSISDN/Number  \
# count   150000.000000  1.500000e+05  1.494310e+05   1.489350e+05
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 149996    False
# 149997    False
# 149998    False
# 149999    False
# 150000    False
# Length: 150001, dtype: bool

# %%
#2 Handling Missing data
# how many missing values exist or better still what is the % of missing values in the dataset?
def percent_missing(df):

    # Calculate total number of cells in dataframe
    totalCells = np.product(df.shape)

    # Count number of missing values per column
    missingCount = df.isnull().sum()

    # Calculate total number of missing values
    totalMissing = missingCount.sum()

    # Calculate percentage of missing values
    print("The dataset contains", round(((totalMissing/totalCells) * 100), 2), "%", "missing values.")

# %%
# percent missing of total data
percent_missing(df)
# Out:
# The dataset contains 12.5 % missing values.

# %%
# Now which column(s) has missing values
df.isna().sum()
# Out:
# Bearer Id                                      991
# Start                                            1
# Start ms                                         1
# End                                              1
# End ms                                           1
# Dur. (ms)                                        1
# IMSI                                           570
# MSISDN/Number                                 1066
# IMEI                                           572
# Last Location Name                            1153
# Avg RTT DL (ms)                              27829
# Avg RTT UL (ms)                              27812
# Avg Bearer TP DL (kbps)                          1
# Avg Bearer TP UL (kbps)                          1
# TCP DL Retrans. Vol (Bytes)                  88146
# TCP UL Retrans. Vol (Bytes)                  96649
# DL TP < 50 Kbps (%)                            754
# 50 Kbps < DL TP < 250 Kbps (%)                 754
# ...

# %%
df['Avg RTT DL (ms)'].median()
# Out:
# 45.0

# %%
df['Avg RTT DL (ms)'].fillna(df['Avg RTT DL (ms)'].median(), inplace=True)

# %%
df['Avg Bearer TP DL (kbps)'].median()
# Out:
# 63.0

# %%
df['Avg Bearer TP DL (kbps)'].fillna(df['Avg Bearer TP DL (kbps)'].median(), inplace=True)

# %%
df['Avg RTT UL (ms)'].median()
# Out:
# 5.0

# %%
df['Avg RTT UL (ms)'].fillna(df['Avg RTT UL (ms)'].median(), inplace=True)

# %%
df.dropna(axis=(0), inplace=True)

# %%
df.isnull().sum()
# Out:
# Bearer Id                                   0
# Start                                       0
# Start ms                                    0
# End                                         0
# End ms                                      0
# Dur. (ms)                                   0
# IMSI                                        0
# MSISDN/Number                               0
# IMEI                                        0
# Last Location Name                          0
# Avg RTT DL (ms)                             0
# Avg RTT UL (ms)                             0
# Avg Bearer TP DL (kbps)                     0
# Avg Bearer TP UL (kbps)                     0
# TCP DL Retrans. Vol (Bytes)                 0
# TCP UL Retrans. Vol (Bytes)                 0
# DL TP < 50 Kbps (%)                         0
# 50 Kbps < DL TP < 250 Kbps (%)              0
# 250 Kbps < DL TP < 1 Mbps (%)               0
# DL TP > 1 Mbps (%)                          0
# ...

# %%
#top 10 handsets used by the customers.

df['Handset Type'].value_counts().head(10)
# Out:
# Handset Type
# Huawei B528S-23A                8839
# Huawei E5180                     797
# Apple iPhone 7 (A1778)           523
# Apple iPhone Xr (A2105)          513
# Apple iPhone 6S (A1688)          507
# Apple iPhone 6 (A1586)           503
# undefined                        451
# Apple iPhone X (A1901)           429
# Apple iPhone 8 (A1905)           428
# Samsung Galaxy S8 (Sm-G950F)     387
# Name: count, dtype: int64

# %%
#top 3 handset manufacturers
df['Handset Manufacturer'].value_counts().head(3)
# Out:
# Handset Manufacturer
# Huawei     10434
# Apple       4362
# Samsung     1984
# Name: count, dtype: int64

# %%
def univariate_categorical(MSISDNNumber):
          print('\nNumber of unique values => ' + str(len(df['MSISDN/Number'].unique())) + '\n\n')
      
plt.figure(figsize=(15, 8))  
y = "count"   
plt.subplot(1, 2, 1)   
sns.countplot(df['MSISDN/Number'])
count_df = df['End'].value_counts().rename(y).reset_index().rename(columns={"index":'MSISDN/Number'})
y= "percent(%)"   
percent_df = df['MSISDN/Number'].value_counts(normalize=True).rename().reset_index().rename(columns={"index":'MSISDN/Number'}) 
plt.subplot(1, 2, 2)   
sns.barplot(percent_df['MSISDN/Number'], percent_df['MSISDN/Number'], data=percent_df) 
plt.show()   
print(tabulate(pd.merge(percent_df, count_df, how='inner'), headers='keys', tablefmt='fancy_grid'))
univariate_categorical('MSISDN/Number')

# %%
sns.distplot(df['Gaming DL (Bytes)'], rug=True)
plt.show()
# Out:
# /tmp/ipykernel_6814/3120605325.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Gaming DL (Bytes)'], rug=True)

# %%
sns.distplot(df['Google DL (Bytes)'], rug=True)
plt.show()
# Out:
# /tmp/ipykernel_6814/1129973638.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Google DL (Bytes)'], rug=True)

# %%
sns.distplot(df['Social Media DL (Bytes)'], rug=True)
plt.show()
# Out:
# /tmp/ipykernel_6814/1988972808.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Social Media DL (Bytes)'], rug=True)

# %%
sns.distplot(df['Youtube DL (Bytes)'], rug=True)
plt.show()
# Out:
# /tmp/ipykernel_6814/1368549468.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Youtube DL (Bytes)'], rug=True)

# %%
print(df['Total UL (Bytes)'].min())
print(df['Total UL (Bytes)'].max())
# Out:
# 4661082.0
# 76607067.0

# %%
df.corr()

# %%
df.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
df['Start_col']=df['Start'].astype(object).replace('/','.').astype(str)

# %%
import warnings
warnings.filterwarnings('ignore')
df['End_col']=df['End'].float.replace('/','.').astype(objects)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4630/4236666449.py in ?()
#       1 import warnings
#       2 warnings.filterwarnings('ignore')
# ----> 3 df['End_col']=df['End'].float.replace('/','.').astype(objects)
#
# ~/week1/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'float'

# %%
df.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Netflix DL (Bytes)  Netflix UL (Bytes)  \
# 0  9.16456699548519E+015  ...           8198936.0           9656251.0
# 1                L77566A  ...          18338413.0          17227132.0
# ...

# %%
sns.plot_hist(df, "Total UL (Bytes)", "blue")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 sns.plot_hist(df, "Total UL (Bytes)", "blue")
#
# AttributeError: module 'seaborn' has no attribute 'plot_hist'
